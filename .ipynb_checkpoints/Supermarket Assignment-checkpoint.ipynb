# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
superm_train=pd.read_csv('supermarket/train.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-6457cd0726b3> in <module>
# ----> 1 superm_train = pd.read_csv('supermarket/train.csv')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
# ...

# %% [markdown]
# # EDA

# %%
superm_train.head()
# Out:
#   Product_Identifier Supermarket_Identifier Product_Supermarket_Identifier  \
# 0              DRA12            CHUKWUDI010              DRA12_CHUKWUDI010
# 1              DRA12            CHUKWUDI013              DRA12_CHUKWUDI013
# 2              DRA12            CHUKWUDI017              DRA12_CHUKWUDI017
# 3              DRA12            CHUKWUDI018              DRA12_CHUKWUDI018
# 4              DRA12            CHUKWUDI035              DRA12_CHUKWUDI035
#
#    Product_Weight Product_Fat_Content  Product_Shelf_Visibility Product_Type  \
# 0            11.6             Low Fat                  0.068535  Soft Drinks
# 1            11.6             Low Fat                  0.040912  Soft Drinks
# 2            11.6             Low Fat                  0.041178  Soft Drinks
# 3            11.6             Low Fat                  0.041113  Soft Drinks
# 4            11.6       Ultra Low fat                  0.000000  Soft Drinks
#
# ...

# %%
superm_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4990 entries, 0 to 4989
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Product_Identifier              4990 non-null   object
#  1   Supermarket_Identifier          4990 non-null   object
#  2   Product_Supermarket_Identifier  4990 non-null   object
#  3   Product_Weight                  4188 non-null   float64
#  4   Product_Fat_Content             4990 non-null   object
#  5   Product_Shelf_Visibility        4990 non-null   float64
#  6   Product_Type                    4990 non-null   object
#  7   Product_Price                   4990 non-null   float64
#  8   Supermarket_Opening_Year        4990 non-null   int64
#  9   Supermarket _Size               3540 non-null   object
#  10  Supermarket_Location_Type       4990 non-null   object
#  11  Supermarket_Type                4990 non-null   object
# ...

# %% [markdown]
# # Data Preprocessing

# %%
#Checking for missing value
superm_train.isnull().sum()
# Out:
# Product_Identifier                   0
# Supermarket_Identifier               0
# Product_Supermarket_Identifier       0
# Product_Weight                     802
# Product_Fat_Content                  0
# Product_Shelf_Visibility             0
# Product_Type                         0
# Product_Price                        0
# Supermarket_Opening_Year             0
# Supermarket _Size                 1450
# Supermarket_Location_Type            0
# Supermarket_Type                     0
# Product_Supermarket_Sales            0
# dtype: int64

# %%
mean=superm_train['Product_Weight'].mean()
superm_train['Product_Weight'].fillna(mean,inplace=True)
mode_size=superm_train['Supermarket _Size'].mode()
superm_train['Supermarket _Size'].fillna(mode_size[0],inplace=True)

# %%
mean
# Out:
# 12.908838347659676

# %%
mode_size
# Out:
# 0    Medium
# dtype: object

# %%
superm_train.isnull().sum()
# Out:
# Product_Identifier                0
# Supermarket_Identifier            0
# Product_Supermarket_Identifier    0
# Product_Weight                    0
# Product_Fat_Content               0
# Product_Shelf_Visibility          0
# Product_Type                      0
# Product_Price                     0
# Supermarket_Opening_Year          0
# Supermarket _Size                 0
# Supermarket_Location_Type         0
# Supermarket_Type                  0
# Product_Supermarket_Sales         0
# dtype: int64

# %% [markdown]
# # Converting Categorical to Numerical

# %%
y=superm_train['Product_Supermarket_Sales']
x=superm_train.drop('Product_Supermarket_Sales',axis=1)

# %%
x=pd.get_dummies(x,drop_first=True)

# %%
x
# Out:
#       Product_Weight  Product_Shelf_Visibility  Product_Price  \
# 0          11.600000                  0.068535         357.54
# 1          11.600000                  0.040912         355.79
# 2          11.600000                  0.041178         350.79
# 3          11.600000                  0.041113         355.04
# 4          11.600000                  0.000000         354.79
# ...              ...                       ...            ...
# 4985       12.908838                  0.145952         402.39
# 4986       12.908838                  0.082956         410.14
# 4987       14.650000                  0.083528         406.14
# 4988       14.650000                  0.083359         404.89
# 4989       14.650000                  0.083489         403.39
#
#       Supermarket_Opening_Year  Product_Identifier_DRA24  \
# 0                         2005                         0
# 1                         1994                         0
# ...

# %% [markdown]
# # Cross validaton

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=1995)

# %% [markdown]
# # Feature Scaling

# %%
#from sklearn.preprocessing import StandardScaler

# %%
#sc=StandardScaler()

# %%
#x_train=sc.fit_transform(x_train)
#x_test=sc.transform(x_test)

# %% [markdown]
# # LinearModel training

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn import utils

# %%
lab_enc= LabelEncoder()
train_encoded=lab_enc.fit_transform(y_train)
print(train_encoded)
print(utils.multiclass.type_of_target(y_train))
print(utils.multiclass.type_of_target(y_train.astype('int')))
print(utils.multiclass.type_of_target(train_encoded))
# Out:
# [ 873  592  339 ...  121  447 2043]
# continuous
# multiclass
# multiclass

# %%
lr.fit(x_train,train_encoded)
print("LogisticRegression")
print(lr.predict(prediction_data_test))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-68d88e029895> in <module>
# ----> 1 lr.fit(x_train,train_encoded)
#       2 print("LogisticRegression")
#       3 print(lr.predict(prediction_data_test))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1404         else:
#    1405             prefer = 'processes'
# -> 1406         fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#    1407                                **_joblib_parallel_args(prefer=prefer))(
#    1408             path_func(X, y, pos_class=class_, Cs=[C_],
#
# ~/opt/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1039             # remaining jobs.
#    1040             self._iterating = False
# -> 1041             if self.dispatch_one_batch(iterator):
# ...

# %%
x_train

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
rf_classifier=RandomForestClassifier(random_state=1995)

# %%
rf_classifier.fit(x_train,y_train)

# %%
lr.fit(x_train,y_train)
